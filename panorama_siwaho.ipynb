# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import glob, os
    
def make_panorama(IMG_NAME):
    img_list = []
    img_list.append(glob.glob(os.path.join('C:\\Users\\USER\\Downloads\\panorama_test\\',IMG_NAME,'*.jpg')))
    img_list = sorted(img_list)
    print(img_list)
    cnt = 0
    for i in img_list:
        if not i:
            cnt +=1
    img_list = img_list[cnt]
    mode = cv2.STITCHER_PANORAMA

    if int(cv2.__version__[0]) == 3:
        stitcher = cv2.createStitcher(mode)
    else:
        stitcher = cv2.Stitcher_create(mode)
    imgs = []
    for i,img_path in enumerate(img_list):
        img = cv2.imread(img_path)
        imgs.append(img)
        status,stitched = stitcher.stitch(imgs)
    if status == 0:
        cv2.imwrite(os.path.join('C:\\Users\\USER\\Downloads\\panorama_test\\result\\',IMG_NAME+'_result.jpg'),stitched)
    gray = cv2.cvtColor(stitched,cv2.COLOR_BGR2GRAY)
    thresh = cv2.bitwise_not(cv2.threshold(gray,0,255,cv2.THRESH_BINARY)[1])
    thresh = cv2.medianBlur(thresh,5)
    stitched_copy = stitched.copy()
    thresh_copy = thresh.copy()

    while np.sum(thresh_copy) > 0:
        thresh_copy = thresh_copy[1:-1,1:-1]
        stitched_copy = stitched_copy[1:-1,1:-1]
    cv2.imwrite(os.path.join('C:\\Users\\USER\\Downloads\\panorama_test\\result\\',IMG_NAME+'_crop.jpg'),stitched_copy)
    plt.figure(figsize=(20,20))
    plt.imshow(cv2.cvtColor(stitched_copy,cv2.COLOR_BGR2RGB))

# %%
make_panorama("bbul1")
# Out:
# [['C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615_01.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615_02.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615_03.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615_04.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615_05.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\bbul1\\KakaoTalk_20210504_103503615_06.jpg']]

# %%
make_panorama("env_back")
# Out:
# [['C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_01.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_02.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_03.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_04.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_05.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_06.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\env_back\\KakaoTalk_20210504_110005452_07.jpg']]

# %%
make_panorama("egg_1")
# Out:
# [['C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_01.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_02.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_03.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_04.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_05.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_06.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_07.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_1\\KakaoTalk_20210504_123610970_08.jpg']]

# %%
make_panorama("egg_2")
# Out:
# [['C:\\Users\\USER\\Downloads\\panorama_test\\egg_2\\KakaoTalk_20210504_123905994.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_2\\KakaoTalk_20210504_123905994_01.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_2\\KakaoTalk_20210504_123905994_02.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_2\\KakaoTalk_20210504_123905994_03.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_2\\KakaoTalk_20210504_123905994_04.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_2\\KakaoTalk_20210504_123905994_05.jpg']]

# %%
make_panorama("egg_3")
# Out:
# [['C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_01.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_02.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_03.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_04.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_05.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_06.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_07.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_3\\KakaoTalk_20210504_131202663_08.jpg']]

# %%
make_panorama("egg_4")
# Out:
# [['C:\\Users\\USER\\Downloads\\panorama_test\\egg_4\\KakaoTalk_20210504_131741011.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_4\\KakaoTalk_20210504_131741011_01.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_4\\KakaoTalk_20210504_131741011_02.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_4\\KakaoTalk_20210504_131741011_03.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_4\\KakaoTalk_20210504_131741011_04.jpg', 'C:\\Users\\USER\\Downloads\\panorama_test\\egg_4\\KakaoTalk_20210504_131741011_05.jpg']]
